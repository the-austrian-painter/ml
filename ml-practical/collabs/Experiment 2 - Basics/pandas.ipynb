# %%
# Out:
#   File "/tmp/ipython-input-3704572794.py", line 162
#     people["over_30"] = people["age"] > 30import numpy as np
#                                          ^
# SyntaxError: invalid decimal literal
