# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('/content/drive/MyDrive/ml-practical/datasets/HRPDataset.csv')

# %%
dataset.head()
# Out:
#    Area    Price
# 0   400  2700000
# 1   425  2837500
# 2   450  2975000
# 3   475  3112500
# 4   500  3250000

# %%
X=dataset[['Area']]

# %%
Y=dataset[['Price']]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

# %%
print(f"Slope (m): {model.coef_[0]}")
print(f"Intercept (b): {model.intercept_}")
print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Slope (m): [5500.]
# Intercept (b): [500000.]
# Mean Squared Error: 4.336808689942018e-19
# R^2 Score: 1.0

# %%
plt.scatter(X, Y, color='blue', label='Actual Price')
plt.plot(X, model.predict(X), color='red', label='Predicted Price')
plt.xlabel('Area (sq ft)')
plt.ylabel('Selling Price ($)')
plt.title('Linear Regression: Property Price Prediction')
plt.legend()
plt.show()
